# %% [markdown]
# # Employee SQL Bonus
# ### Importing from SQL database using SQLalchemy.

# %%
# !pip install psycopg2
#!pip install psycopg2-binary --luisf

# %%
#Import and Dependencies
import pandas as pd
import sqlalchemy as sql
import pprint
import matplotlib.pyplot as plt
import psycopg2
import numpy as np

from config import password

# %% [markdown]
# ### Importing from SQL database using SQLalchemy.

# %%
# Create engine and connection
# https://docs.sqlalchemy.org/en/13/core/connections.html?highlight=engine%20connect#sqlalchemy.engine.Connection
engine = sql.create_engine(f'postgresql://postgres:{password}@localhost:5432/Employee_SQL-Challenge')
conn = engine.connect()

# %% [markdown]
# ### Import tables

# %%
# Query Import the departments table
departments = pd.read_sql('select * from departments', conn)
departments
# Out:
#   dept_no           dept_name
# 0    d001           Marketing
# 1    d002             Finance
# 2    d003     Human Resources
# 3    d004          Production
# 4    d005         Development
# 5    d006  Quality Management
# 6    d007               Sales
# 7    d008            Research
# 8    d009    Customer Service

# %%
# Import the Employees table
employees = pd.read_sql('select * from employees', conn)
employees
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# ...

# %%
# Import the Salaries table
salaries = pd.read_sql('select * from salaries', conn)
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
# Import the Department Manager table
dept_manager = pd.read_sql('select * from dept_manager', conn)
dept_manager
# Out:
#    dept_no  emp_no
# 0     d001  110022
# 1     d001  110039
# 2     d002  110085
# 3     d002  110114
# 4     d003  110183
# 5     d003  110228
# 6     d004  110303
# 7     d004  110344
# 8     d004  110386
# 9     d004  110420
# 10    d005  110511
# 11    d005  110567
# 12    d006  110725
# 13    d006  110765
# 14    d006  110800
# 15    d006  110854
# 16    d007  111035
# 17    d007  111133
# 18    d008  111400
# 19    d008  111534
# 20    d009  111692
# 21    d009  111784
# 22    d009  111877
# 23    d009  111939

# %%
# Import the Titles table
titles = pd.read_sql('select * from titles', conn)
titles
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer
# 5    e0004    Technique Leader
# 6    m0001             Manager

# %% [markdown]
# ## 2.  Create a histogram to visualize the most common salary ranges for employees.

# %%
#plot using pandas
salaries.hist(column='salary', by=None, grid=True, xlabelsize=None, xrot=None, ylabelsize=None, 
              yrot=None, ax=None, sharex=False, sharey=False, figsize=None, layout=None, 
              bins=5, backend=None)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B3ECC7B130>]],
#       dtype=object)

# %%
#plot using matplotlib and few bins

plt.hist(salaries['salary'], 10, density=False, label="Salary")
plt.axvline(salaries['salary'].mean(), color='g', linestyle='dashed', linewidth=1, label="Salary Mean")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.legend() 
plt.title("Common Salary Ranges")
plt.savefig("Common Salary Ranges.png")

# %%
#plot using matplotlib and a lot of bins

plt.hist(salaries['salary'], 50, density=False, label="Salary")
plt.axvline(salaries['salary'].mean(), color='k', linestyle='dashed', linewidth=1, label="Salary Mean")
plt.xlabel("Salary")
plt.ylabel("Number of Employees")
plt.legend() 
plt.title("Common Salary Ranges")
#plt.savefig("Common Salary Ranges.png")

# %% [markdown]
# ## 3. Create a bar chart of average salary by title.

# %%
#Join salaries and titles using employees dataframe as intermediate.
#merge employees and salaries, inner join, 
empl_slr = employees.merge(salaries, on='emp_no')
empl_slr
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date  salary
# 0       1990-04-28   40000
# 1       1991-09-07   53422
# 2       1992-03-21   48973
# 3       1987-11-26   40000
# ...

# %%
#merge title dataframe to the brand new dataframe created
est = empl_slr.merge(titles, left_on='emp_title_id', right_on='title_id', how='outer')

est
# Out:
#         emp_no emp_title_id  birth_date  first_name   last_name sex  \
# 0       473302        s0001  1953-07-25    Hideyuki    Zallocco   M
# 1       421786        s0001  1957-09-28       Xiong    Verhoeff   M
# 2       273487        s0001  1957-04-14   Christoph     Parfitt   M
# 3       246449        s0001  1958-03-23       Subbu  Bultermann   F
# 4        48085        s0001  1964-01-19  Venkatesan        Gilg   M
# ...        ...          ...         ...         ...         ...  ..
# 300019  111400        m0001  1959-11-09        Arie     Staelin   M
# 300020  111133        m0001  1955-03-16       Hauke       Zhang   M
# 300021  110085        m0001  1959-10-28        Ebru       Alpin   M
# 300022  110386        m0001  1953-10-04        Shem      Kieras   M
# 300023  111784        m0001  1956-06-14       Marjo  Giarratana   F
#
#          hire_date  salary title_id    title
# 0       1990-04-28   40000    s0001    Staff
# 1       1987-11-26   40000    s0001    Staff
# ...

# %%
#group by title and then get the mean of salaries by title

egbt = est.groupby(['title'])['salary'].mean()
egbt
# Out:
# title
# Assistant Engineer    48564.434447
# Engineer              48535.336511
# Manager               51531.041667
# Senior Engineer       48506.799871
# Senior Staff          58550.172704
# Staff                 58465.382850
# Technique Leader      48582.896092
# Name: salary, dtype: float64

# %%
# plot using pandas

egbt.plot.bar(rot=55)

# %%
query1 = pd.read_sql("SELECT * FROM salaries INNER JOIN employees ON salaries.emp_no = employees.emp_no",conn)
query1
# Out:
#         emp_no  salary  emp_no emp_title_id  birth_date first_name  \
# 0        10005   78228   10005        s0001  1955-01-21    Kyoichi
# 1        10010   72488   10010        e0002  1963-06-01  Duangkaew
# 2        10011   42365   10011        s0001  1953-11-07       Mary
# 3        10013   40000   10013        s0002  1963-06-07  Eberhardt
# 4        10017   71380   10017        s0001  1958-07-06  Cristinel
# ...        ...     ...     ...          ...         ...        ...
# 300019  499948   40000  499948        e0002  1953-05-24   Cordelia
# 300020  499972   41002  499972        e0003  1957-07-25     Katsuo
# 300021  499985   40000  499985        s0001  1964-12-26       Gila
# 300022  499987   52282  499987        s0001  1961-09-05      Rimli
# 300023  499998   40000  499998        s0001  1956-09-05   Patricia
#
#           last_name sex   hire_date
# 0          Maliniak   M  1989-09-12
# 1          Piveteau   F  1989-08-24
# 2             Sluis   F  1990-01-22
# ...

# %%
query2 = pd.read_sql("SELECT * FROM salaries INNER JOIN employees ON salaries.emp_no = employees.emp_no LEFT JOIN titles ON employees.emp_title_id=titles.title_id",conn)
query2
# Out:
#         emp_no  salary  emp_no emp_title_id  birth_date first_name  \
# 0        10005   78228   10005        s0001  1955-01-21    Kyoichi
# 1        10010   72488   10010        e0002  1963-06-01  Duangkaew
# 2        10011   42365   10011        s0001  1953-11-07       Mary
# 3        10013   40000   10013        s0002  1963-06-07  Eberhardt
# 4        10017   71380   10017        s0001  1958-07-06  Cristinel
# ...        ...     ...     ...          ...         ...        ...
# 300019  499948   40000  499948        e0002  1953-05-24   Cordelia
# 300020  499972   41002  499972        e0003  1957-07-25     Katsuo
# 300021  499985   40000  499985        s0001  1964-12-26       Gila
# 300022  499987   52282  499987        s0001  1961-09-05      Rimli
# 300023  499998   40000  499998        s0001  1956-09-05   Patricia
#
#           last_name sex   hire_date title_id            title
# 0          Maliniak   M  1989-09-12    s0001            Staff
# ...

# %%
# Store the query
avg_salaries_by_title = query2.groupby(["title"]).mean()["salary"]
avg_salaries_by_title
# Out:
# title
# Assistant Engineer    48564.434447
# Engineer              48535.336511
# Manager               51531.041667
# Senior Engineer       48506.799871
# Senior Staff          58550.172704
# Staff                 58465.382850
# Technique Leader      48582.896092
# Name: salary, dtype: float64

# %%
# Plot the Barchart
title_list = avg_salaries_by_title.index
avg_salary_for_title = avg_salaries_by_title.values

x_axis = np.arange(len(title_list))
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, title_list, rotation=45)
plt.title("Average Salary By Title")
plt.xlabel("Title")
plt.ylabel("Average Salary ($)")
plt.grid(axis="y")
chart = plt.bar(x_axis, avg_salary_for_title, color="g", alpha=0.75, align="center")

for i in chart:
    yvalue = i.get_height()
    plt.text(i.get_x(), yvalue + 500, "${:,.2f}K".format(yvalue/1000))
    
plt.show()
plt.savefig("AvgSalaryByTitle.png")

# %% [markdown]
# #### What is my employee number?

# %%
est.query("emp_no == 499942")
# Out:
#         emp_no emp_title_id  birth_date first_name last_name sex   hire_date  \
# 287532  499942        e0004  1963-01-10      April  Foolsday   F  1997-02-10
#
#         salary title_id             title
# 287532   40000    e0004  Technique Leader
